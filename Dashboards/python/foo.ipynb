# %%
from dash import Dash, html, dash_table, dcc, callback, Output, Input, register_page
import plotly.express as px
import pandas as pd
import dash_ag_grid as dag
from wtf.dd import DD
sales = pd.read_csv("Dta/output/sorted_all_ads.csv")
sales
# Out:
#           Datum  Impressionen  Klicks  Kosten     CPC     CTR Provider
# 0    2024-11-22         305.0       9    5.00  0.5556  0.0295    Alpha
# 1    2024-11-22         480.0      23    2.00  0.0870  0.0479     Meta
# 2    2024-11-23         663.0      42    4.61  0.1098  0.0633     Meta
# 3    2024-11-23         867.0       9    3.99  0.4433  0.0104    Alpha
# 4    2024-11-24         823.0      71    4.98  0.0701  0.0863     Meta
# ..          ...           ...     ...     ...     ...     ...      ...
# 547  2025-08-23           0.0       0    0.00  0.0000  0.0000     Meta
# 548  2025-08-23        2348.0      54   10.39  0.1924  0.0230     Meta
# 549  2025-08-24           0.0       0    0.00  0.0000  0.0000    Alpha
# 550  2025-08-24           0.0       0    0.00  0.0000  0.0000     Meta
# 551  2025-08-24        4371.0      93   16.38  0.1761  0.0213     Meta
#
# [552 rows x 7 columns]

# %%
fig = px.bar(sales , x="Datum", y="Impressionen", color='Provider')
ymax = sales["Nettoumsatz"].max()
fig.update_yaxes(range=[0, ymax])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/projx/final_proj_dcda/.venv/lib/python3.14/site-packages/IPython/core/formatters.py:984, in IPythonDisplayFormatter.__call__(self, obj)
#     982 method = get_real_method(obj, self.print_method)
#     983 if method is not None:
# --> 984     method()
#     985     return True
#
# File ~/projx/final_proj_dcda/.venv/lib/python3.14/site-packages/plotly/basedatatypes.py:850, in BaseFigure._ipython_display_(self)
#     847 import plotly.io as pio
#     849 if pio.renderers.render_on_display and pio.renderers.default:
# --> 850     pio.show(self)
#     851 else:
#     852     print(repr(self))
#
# File ~/projx/final_proj_dcda/.venv/lib/python3.14/site-packages/plotly/io/_renderers.py:415, in show(fig, renderer, validate, **kwargs)
#     410     raise ValueError(
# ...

# %%
import plotly.graph_objects as go

f = go.FigureWidget()
f
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[14], line 3
#       1 import plotly.graph_objects as go
# ----> 3 f = go.FigureWidget()
#       4 f
#
# File ~/projx/final_proj_dcda/.venv/lib/python3.14/site-packages/plotly/missing_anywidget.py:13, in FigureWidget.__init__(self, *args, **kwargs)
#      12 def __init__(self, *args, **kwargs):
# ---> 13     raise ImportError("Please install anywidget to use the FigureWidget class")
#
# ImportError: Please install anywidget to use the FigureWidget class

# %%
import plotly.express as px
df = px.data.carshare()

df.head(6)
# Out:
#    centroid_lat  centroid_lon    car_hours  peak_hour
# 0     45.471549    -73.588684  1772.750000          2
# 1     45.543865    -73.562456   986.333333         23
# 2     45.487640    -73.642767   354.750000         20
# 3     45.522870    -73.595677   560.166667         23
# 4     45.453971    -73.738946  2836.666667         19
# 5     45.573126    -73.539902  1022.750000          1

# %%
fig = px.scatter_map(df, lat="centroid_lat", lon="centroid_lon", color="peak_hour", size="car_hours",
                  color_continuous_scale=px.colors.cyclical.IceFire, size_max=15, zoom=10,
                  map_style="carto-positron")
fig
#fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/projx/final_proj_dcda/.venv/lib/python3.14/site-packages/IPython/core/formatters.py:984, in IPythonDisplayFormatter.__call__(self, obj)
#     982 method = get_real_method(obj, self.print_method)
#     983 if method is not None:
# --> 984     method()
#     985     return True
#
# File ~/projx/final_proj_dcda/.venv/lib/python3.14/site-packages/plotly/basedatatypes.py:850, in BaseFigure._ipython_display_(self)
#     847 import plotly.io as pio
#     849 if pio.renderers.render_on_display and pio.renderers.default:
# --> 850     pio.show(self)
#     851 else:
#     852     print(repr(self))
#
# File ~/projx/final_proj_dcda/.venv/lib/python3.14/site-packages/plotly/io/_renderers.py:415, in show(fig, renderer, validate, **kwargs)
#     410     raise ValueError(
# ...

# %%
import plotly.express as px

df = px.data.stocks()
df.head(23)
# Out:
#           date      GOOG      AAPL      AMZN        FB      NFLX      MSFT
# 0   2018-01-01  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 1   2018-01-08  1.018172  1.011943  1.061881  0.959968  1.053526  1.015988
# 2   2018-01-15  1.032008  1.019771  1.053240  0.970243  1.049860  1.020524
# 3   2018-01-22  1.066783  0.980057  1.140676  1.016858  1.307681  1.066561
# 4   2018-01-29  1.008773  0.917143  1.163374  1.018357  1.273537  1.040708
# 5   2018-02-05  0.941528  0.893771  1.089868  0.942521  1.188009  0.999887
# 6   2018-02-12  0.993259  0.985314  1.178621  0.949211  1.326349  1.043202
# 7   2018-02-19  1.022282  1.002857  1.220365  0.980947  1.361636  1.066561
# 8   2018-02-26  0.978852  1.006914  1.220569  0.945250  1.433640  1.055108
# 9   2018-03-05  1.052448  1.028457  1.284549  0.991330  1.578361  1.094682
# 10  2018-03-12  1.030393  1.017257  1.278683  0.990581  1.516501  1.072684
# ...

# %%
fig = px.line(df, x="date", y=df.columns,
              hover_data={"date": "|%B %d, %Y"},
              title='custom tick labels')
fig.update_xaxes(
    dtick="M1",
    tickformat="%b\n%Y")
fig#.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/projx/final_proj_dcda/.venv/lib/python3.14/site-packages/IPython/core/formatters.py:984, in IPythonDisplayFormatter.__call__(self, obj)
#     982 method = get_real_method(obj, self.print_method)
#     983 if method is not None:
# --> 984     method()
#     985     return True
#
# File ~/projx/final_proj_dcda/.venv/lib/python3.14/site-packages/plotly/basedatatypes.py:850, in BaseFigure._ipython_display_(self)
#     847 import plotly.io as pio
#     849 if pio.renderers.render_on_display and pio.renderers.default:
# --> 850     pio.show(self)
#     851 else:
#     852     print(repr(self))
#
# File ~/projx/final_proj_dcda/.venv/lib/python3.14/site-packages/plotly/io/_renderers.py:415, in show(fig, renderer, validate, **kwargs)
#     410     raise ValueError(
# ...

# %%
import plotly.express as px

sales.head()
# Out:
#         Datum  Impressionen  Klicks  Kosten     CPC     CTR Provider
# 0  2024-11-22         305.0       9    5.00  0.5556  0.0295    Alpha
# 1  2024-11-22         480.0      23    2.00  0.0870  0.0479     Meta
# 2  2024-11-23         663.0      42    4.61  0.1098  0.0633     Meta
# 3  2024-11-23         867.0       9    3.99  0.4433  0.0104    Alpha
# 4  2024-11-24         823.0      71    4.98  0.0701  0.0863     Meta

# %%
df = sales
fig = px.scatter(
    df, x='Datum', y='Impressionen', opacity=0.65,
    trendline='ols', trendline_color_override='darkblue'
)
fig#.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 2
#       1 df = sales
# ----> 2 fig = px.scatter(
#       3     df, x='Datum', y='Impressionen', opacity=0.65,
#       4     trendline='Klicks', trendline_color_override='darkblue'
#       5 )
#       6 fig#.show()
#
# ...
