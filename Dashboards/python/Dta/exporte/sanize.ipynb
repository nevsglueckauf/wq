# %% [markdown]
# ### Sanitizing data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

df = pd.read_csv("sessions.csv")
df['datum'] = pd.to_datetime(df['datum'], format='%Y-%m-%d')
df["cr"] = round(df["sess_co_done"]/df["sessions"], 3)

print(df['datum'].min(), df['datum'].max())
#df.sort_values("cr", ascending=False)
#prt = df[["","jump_offs", "sess_cart_add", "sess_co", "sess_co_done", "sessions"]]
part = df[["jump_offs", "sess_cart_add", "sess_co", "sess_co_done", "sessions"]].sum()
part.to_csv("kpi.csv")
# Out:
# 2024-10-01 00:00:00 2025-08-01 00:00:00

# %%
sns.lineplot(df, x="datum", y="sessions", label="Sitzungen")
sns.lineplot(df, x="datum", y="sess_co_done", label="CO abgeschl.")
sns.lineplot(df, x="datum", y="sess_co", label="CO err.")
sns.lineplot(df, x="datum", y="sess_cart_add", label="Warenkorb")
plt.legend(loc='lower right')
 
# Add a grid
plt.grid(True)
plt.show()

# %%
px.line(df, x="datum", y="sess_cart_add")
plt.show()

# %%
df["cr"] = round(df["sess_co_done"]/df["sessions"], 3)
max = df["cr"].max()
min = df["cr"].min()
avg = df["cr"].mean()
sesssions = df["sessions"].sum()

[max, min, avg]
# Out:
# [np.float64(1.0), np.float64(0.0), np.float64(0.014856108597285068)]

# %%
df["sess_type"] = "Absprung"
co = df[[ 'datum', 'sess_ctry', 'sess_loc','sug_platform', 'landing_uri',
        'session_duration', 'pages_per_sess', 'jump_offs', "sess_type"]]

co.to_csv("_jo.csv")
# , 'sess_cart_add','sess_co_done', 'sessions', 'cr'
co
# Out:
#           datum       sess_ctry       sess_loc sug_platform  \
# 0    2024-10-01         Germany      Nuremberg       direct
# 1    2024-10-01         Germany         Munich       direct
# 2    2024-10-01  United Kingdom         London       direct
# 3    2024-10-01         Germany        Hausach       direct
# 4    2024-10-01         Germany      Burgthann       direct
# ...         ...             ...            ...          ...
# 2205 2025-08-01         Germany         Bochum       direct
# 2206 2025-08-01         Germany  Altfraunhofen         meta
# 2207 2025-08-01        Portugal      Guimarães       direct
# 2208 2025-08-01         Germany        Leipzig         meta
# 2209 2025-08-01         Germany         Berlin         meta
#
#                                             landing_uri  session_duration  \
# 0       https://www.whiskyquartier.de/pages/datenschutz        368.000000
# 1     https://www.whiskyquartier.de/products/kavalan...        237.000000
# 2                https://www.whiskyquartier.de/password          0.000000
# 3                      https://7bb991-55.myshopify.com/          0.000000
# 4                      https://7bb991-55.myshopify.com/        327.555556
# ...                                                 ...               ...
# 2205  https://www.whiskyquartier.de/account/subscrib...         42.000000
# 2206  https://www.whiskyquartier.de/?utm_source=FB+W...        102.000000
# 2207  https://www.whiskyquartier.de/products/kavalan...          0.000000
# 2208  https://www.whiskyquartier.de/?utm_source=FB+W...         54.000000
# 2209  https://www.whiskyquartier.de/?utm_source=FB+W...          0.000000
#
#       pages_per_sess  jump_offs sess_type
# 0           5.000000          0  Absprung
# 1           7.000000          0  Absprung
# 2           1.000000          1  Absprung
# 3           1.000000          1  Absprung
# 4           1.888889          7  Absprung
# ...              ...        ...       ...
# 2205        3.000000          0  Absprung
# 2206        2.000000          0  Absprung
# 2207        1.000000          1  Absprung
# 2208        3.000000          0  Absprung
# 2209        1.000000          1  Absprung
#
# [2210 rows x 9 columns]

# %%
df = pd.read_csv("sessions.csv")
df_loc = df.groupby(["sess_ctry", "sess_loc"])['sessions'].sum()
df_loc.to_csv("sess_loc.csv")

# %%
df[df["sess_ctry"] != "Germany"]["sess_loc"].unique()
# Out:
# array(['London', nan, 'Kyiv', 'Montreal', 'Dublin', 'Varna', 'Amsterdam',
#        'Helsinki', 'Gwanak-gu', 'Vila Nova de Famalicão', 'Sisak',
#        'Purmerend', 'Charlottenlund', 'Beroun', 'Doetinchem', 'Singapore',
#        'Prague', 'Narón', 'Clonee', 'Manchester', 'Drunen', 'Bengaluru',
#        'České Budějovice', 'Tokyo', 'Biên Hòa', 'Stockholm', 'Glasgow',
#        "Santa Vittoria d'Alba", 'Pijnacker', 'Hendrik-Ido-Ambacht',
#        'Casal Comba', 'Kabul', 'Luleå', 'Lisbon', 'Vienna', 'Santiago',
#        'Spijkenisse', 'Eindhoven', 'Sofia', 'Alphen aan den Rijn',
#        'Salzburg', 'Nassau', 'Graz', 'Konya', 'Beauharnois',
#        'Santa Coloma de Farners', 'Bupyeong-gu', 'Corbeil-Essonnes',
#        'San José', 'Mons', 'Rotterdam', 'Lucknow', 'Istanbul', 'Rosenau',
#        'Ehrendingen', 'Veldhoven', 'Žatec', 'Ghent', 'Maastricht',
#        'Hong Kong', 'Arnhem', 'St Petersburg', 'Praia', 'Aarau',
#        'Uitikon', 'Český Brod', 'Antwerp', 'Lviv', 'Bandhagen', 'Rząśnik',
#        'Zurich', 'Kaohsiung', 'Taipei', 'Innsbruck', 'West Bromwich',
#        'Mumbai', 'Tallinn', 'Cape Town', 'Kapfenberg', 'Lunteren',
#        'Nordelta', 'Szczecin', 'Rhoon', 'Kigali', 'Malmo', 'Ibadan',
#        'Enschede', 'Nijmegen', 'Warsaw', 'Norrköping', 'Guimarães',
#        'Vught', 'Dubai', 'Verbier', 'Basel', 'Dyatkovo', 'Jesenice',
#        'Ocotlán', 'Rome', 'Moscow', 'Nowa Dęba', 'Itabaianinha',
#        'Zundert', 'Maribor', 'Montrose', 'Joinville', 'Cairo', 'Nitra',
#        'Brussels', 'Oberschützen', 'Spreitenbach', 'Yekaterinburg',
#        'Dunajská Streda', 'Male', 'Venice', 'Wyszków', 'Elixhausen',
#        'Long An', 'Pago Pago', 'Zagreb', 'Geneva',
#        'Ferraz de Vasconcelos', 'Dordrecht', 'Waldkirch', 'Sharjah',
#        'Linköping', 'Ecatepec', 'Baku', 'Minsk', 'Herzliya',
#        'Heerhugowaard', 'Budapest', 'Athens', 'Nabeul', 'Southwark',
#        'Ness Ziona', 'Čitluk', 'Aryanah', 'Bülach', 'Tel Aviv',
#        'Rorschach', 'Mirandela', 'Panningen', 'Copenhagen',
#        'Ho Chi Minh City', 'Larnaca', 'Leicester', 'Reykjavik', 'Skopje',
#        'Dnipro', 'Poznan', 'Naaldwijk', 'Bangkok', 'Vilnius', 'Schiedam',
#        'Southampton', 'Rousse', 'Pardubice', 'Riga', 'Wicklow',
#        'Loughton', 'Santo Domingo', 'Sydney', 'Wervershoof', 'Del Viso',
#        'Dalseo-gu', 'Cambridge', 'Ilford', 'Bucharest', 'Bratislava',
#        'Helmond', 'Varde', 'Belo Horizonte', 'Solec Kujawski', 'Payerne',
#        'Nicosia', 'Tower Hamlets', 'Rødovre Municipality', 'Breda',
#        'Banská Bystrica', 'Brønderslev', 'Amel', 'Karlstad',
#        'Lavilledieu', 'Yangsan', 'Örebro', 'Frauenfeld', 'Luton',
#        'Götzis', 'Utrecht', 'Plovdiv', 'Brønshøj', 'Salem', 'Limassol',
#        'Kinuta', 'City of Westminster', 'Québec', 'Vojens', 'Yambol',
#        'Bialystok', 'Valladolid', 'Lyon', 'Batumi', 'Porto', 'Esbjerg',
#        'Luxembourg', 'Bernex', 'Madrid', 'Gangnam-gu', 'Jenbach',
#        'Dieren', 'Ganei Tikva', 'Jarocin', 'Holstebro', 'Krakow', 'Rønne',
#        'Oudenaarde', 'Gothenburg', 'Tiefgraben', 'Cardiff', 'Pohořelice',
#        'Katowice', 'Alness', 'Cesena', 'Grasse', 'Vári', 'The Hague',
#        'Remetschwil', 'Chiajna', 'Männedorf', 'Adliswil', 'Modena',
#        'Bologna', 'Rijeka', 'Birsfelden', 'Florence', "'s-Hertogenbosch",
#        'Giza', 'Shanghai', 'Milton Keynes', 'Glurns', 'Eunpyeong-gu',
#        'Surat'], dtype=object)

# %%
min = df["datum"].min()
max = df["datum"].max()
f"Im Zeiotraum {min} bis {max}"
# Out:
# 'Im Zeiotraum 2024-10-01 00:00:00 bis 2025-08-01 00:00:00'
