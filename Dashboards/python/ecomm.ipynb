# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("kaggle/evt_cosm_shp/2020-Jan.csv")
#df["event_type"].unique()
# array(['view'	'cart'	'purchase']	dtype=object)
df["date"] = df["event_time"].str[0:10]
#df["date_dt"] = pd.to_datetime(df["date"], "%Y-%m-%d")
#pd.to_datetime(, "%Y-%m-%d")
#df.dtypes
buyers = df[df["event_type"]=="purchase"]
agg = buyers.groupby('user_id').value_counts()
# brands = df["brand"].unique()
# sorted(brands)
agg.tail()
# Out:
# user_id    event_time               event_type  product_id  category_id          category_code                  brand    price  user_session                          date
# 608669019  2020-01-31 15:47:28 UTC  purchase    5901987     2007399943458784057  apparel.glove                  benovy   7.16   85b2c98f-9d4e-4d12-9892-1df7aece7d8a  2020-01-31    1
# 608761018  2020-01-31 20:46:41 UTC  purchase    5855507     1487580006350586771  appliances.environment.vacuum  max      79.21  47104cdb-a17a-4104-86f5-1f75eef1c628  2020-01-31    1
# 608801967  2020-01-31 22:07:10 UTC  purchase    5775814     1487580013053083824  stationery.cartrige            italwax  1.98   6e55ee06-8d58-4b61-ab76-cc9c144e1d9a  2020-01-31    1
#                                                 5787829     1487580013053083824  stationery.cartrige            italwax  3.65   6e55ee06-8d58-4b61-ab76-cc9c144e1d9a  2020-01-31    1
# ...

# %%
sns.lineplot(df[["date", "price"]][df["event_type"]=="purchase"], x="date", y="price")
# Out:
# <Axes: xlabel='date', ylabel='price'>
